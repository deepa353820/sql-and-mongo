# %%
def add(x,y):
    return x+y

num1=10
num2=20
add_result=add(num1,num2)

# %%
import os
import numpy
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('finalTrain.csv')
df.head()
df.columns
df.City
df.describe()
df.info()
df.infer_objects()
# MIssing objects
# Explore about the numerical vriables
# explore about categorical variables
# Finding relationship between features





#open = file.open("")
#eda, feature engineer, train the model, create pipeline, deploy it aws/azure, git/github,docker, any database you can integrage mongodb optional
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45584 entries, 0 to 45583
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           45584 non-null  object
#  1   Delivery_person_ID           45584 non-null  object
#  2   Delivery_person_Age          43730 non-null  float64
#  3   Delivery_person_Ratings      43676 non-null  float64
#  4   Restaurant_latitude          45584 non-null  float64
#  5   Restaurant_longitude         45584 non-null  float64
#  6   Delivery_location_latitude   45584 non-null  float64
#  7   Delivery_location_longitude  45584 non-null  float64
#  8   Order_Date                   45584 non-null  object
#  9   Time_Orderd                  43853 non-null  object
#  10  Time_Order_picked            45584 non-null  object
#  11  Weather_conditions           44968 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# ID                             45557
# Delivery_person_ID             45557
# Delivery_person_Age            45557
# Delivery_person_Ratings        45557
# Restaurant_latitude            45557
# Restaurant_longitude           45557
# Delivery_location_latitude     45557
# Delivery_location_longitude    45557
# Order_Date                     45557
# Time_Orderd                    45557
# Time_Order_picked              45557
# Weather_conditions             45557
# Road_traffic_density           45557
# Vehicle_condition              45557
# Type_of_order                  45557
# Type_of_vehicle                45557
# multiple_deliveries            45558
# Festival                       45557
# City                           45557
# Time_taken (min)               45557
# dtype: int64

# %%
df.head().max
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.max of        ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings
# 0  0xcdcd      DEHRES17DEL01                 36.0                      4.2  \
# 1  0xd987      KOCRES16DEL01                 21.0                      4.7
# 2  0x2784     PUNERES13DEL03                 23.0                      4.7
# 3  0xc8b6     LUDHRES15DEL02                 34.0                      4.3
# 4  0xdb64      KNPRES14DEL02                 24.0                      4.7
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude
# 0            30.327968             78.046106                   30.397968  \
# 1            10.003064             76.307589                   10.043064
# 2            18.562450             73.916619                   18.652450
# 3            30.899584             75.809346                   30.919584
# 4            26.463504             80.372929                   26.593504
#
# ...

# %%
df.head().min
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.min of        ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings
# 0  0xcdcd      DEHRES17DEL01                 36.0                      4.2  \
# 1  0xd987      KOCRES16DEL01                 21.0                      4.7
# 2  0x2784     PUNERES13DEL03                 23.0                      4.7
# 3  0xc8b6     LUDHRES15DEL02                 34.0                      4.3
# 4  0xdb64      KNPRES14DEL02                 24.0                      4.7
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude
# 0            30.327968             78.046106                   30.397968  \
# 1            10.003064             76.307589                   10.043064
# 2            18.562450             73.916619                   18.652450
# 3            30.899584             75.809346                   30.919584
# 4            26.463504             80.372929                   26.593504
#
# ...

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=45584, step=1),
#  Index(['ID', 'Delivery_person_ID', 'Delivery_person_Age',
#         'Delivery_person_Ratings', 'Restaurant_latitude',
#         'Restaurant_longitude', 'Delivery_location_latitude',
#         'Delivery_location_longitude', 'Order_Date', 'Time_Orderd',
#         'Time_Order_picked', 'Weather_conditions', 'Road_traffic_density',
#         'Vehicle_condition', 'Type_of_order', 'Type_of_vehicle',
#         'multiple_deliveries', 'Festival', 'City', 'Time_taken (min)'],
#        dtype='object')]

# %%
df.mean
df.describe()
df.dtypes
# Out:
# ID                              object
# Delivery_person_ID              object
# Delivery_person_Age            float64
# Delivery_person_Ratings        float64
# Restaurant_latitude            float64
# Restaurant_longitude           float64
# Delivery_location_latitude     float64
# Delivery_location_longitude    float64
# Order_Date                      object
# Time_Orderd                     object
# Time_Order_picked               object
# Weather_conditions              object
# Road_traffic_density            object
# Vehicle_condition              float64
# Type_of_order                   object
# Type_of_vehicle                 object
# multiple_deliveries            float64
# Festival                        object
# City                            object
# Time_taken (min)               float64
# dtype: object

# %%
[features for features in df.columns if df[features].isnull().sum()>1]
# Out:
# ['ID',
#  'Delivery_person_ID',
#  'Delivery_person_Age',
#  'Delivery_person_Ratings',
#  'Restaurant_latitude',
#  'Restaurant_longitude',
#  'Delivery_location_latitude',
#  'Delivery_location_longitude',
#  'Order_Date',
#  'Time_Orderd',
#  'Time_Order_picked',
#  'Weather_conditions',
#  'Road_traffic_density',
#  'Vehicle_condition',
#  'Type_of_order',
#  'Type_of_vehicle',
#  'multiple_deliveries',
#  'Festival',
#  'City',
#  'Time_taken (min)']

# %%
import seaborn as sns
print(sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis'))
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %%
city_name=df.City.value_counts().index
city_val=df.City.value_counts().values
print(plt.pie(city_val,labels=city_name))
# Out:
# ([<matplotlib.patches.Wedge object at 0x000001C94C6332D0>, <matplotlib.patches.Wedge object at 0x000001C94C640FD0>, <matplotlib.patches.Wedge object at 0x000001C94C6424D0>], [Text(-0.8205398023996512, 0.7326079665673461, 'Metropolitian'), Text(0.8119803660099053, -0.7420834759071384, 'Urban'), Text(1.0999258860885173, -0.0127689119501388, 'Semi-Urban')])

# %%
df.Type_of_vehicle.count()
# Out:
# 27

# %%
df.tail()
# Out:
#         ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings
# 45579  NaN                NaN                  NaN                      NaN  \
# 45580  NaN                NaN                  NaN                      NaN
# 45581  NaN                NaN                  NaN                      NaN
# 45582  NaN                NaN                  NaN                      NaN
# 45583  NaN                NaN                  NaN                      NaN
#
#        Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude
# 45579                  NaN                   NaN                         NaN  \
# 45580                  NaN                   NaN                         NaN
# 45581                  NaN                   NaN                         NaN
# 45582                  NaN                   NaN                         NaN
# 45583                  NaN                   NaN                         NaN
#
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Delivery_person_ID', 'Delivery_person_Age',
#        'Delivery_person_Ratings', 'Restaurant_latitude',
#        'Restaurant_longitude', 'Delivery_location_latitude',
#        'Delivery_location_longitude', 'Order_Date', 'Time_Orderd',
#        'Time_Order_picked', 'Weather_conditions', 'Road_traffic_density',
#        'Vehicle_condition', 'Type_of_order', 'Type_of_vehicle',
#        'multiple_deliveries', 'Festival', 'City', 'Time_taken (min)'],
#       dtype='object')

# %%
data=df[['ID', 'Delivery_person_ID', 'Delivery_person_Age',
       'Delivery_person_Ratings', 'Restaurant_latitude',
       'Restaurant_longitude', 'Delivery_location_latitude',
       'Delivery_location_longitude']]

# %%
data
a=pd.DataFrame(data)

# %%
data
data1=pd.DataFrame(data)
data1
# Out:
#            ID Delivery_person_ID  Delivery_person_Age
# 0      0xcdcd      DEHRES17DEL01                 36.0  \
# 1      0xd987      KOCRES16DEL01                 21.0
# 2      0x2784     PUNERES13DEL03                 23.0
# 3      0xc8b6     LUDHRES15DEL02                 34.0
# 4      0xdb64      KNPRES14DEL02                 24.0
# ...       ...                ...                  ...
# 45579  0x7c09      JAPRES04DEL01                 30.0
# 45580  0xd641      AGRRES16DEL01                 21.0
# 45581  0x4f8d     CHENRES08DEL03                 30.0
# 45582  0x5eee    COIMBRES11DEL01                 20.0
# 45583  0x5fb2   RANCHIRES09DEL02                 23.0
#
#        Delivery_person_Ratings  Restaurant_latitude  Restaurant_longitude
# 0                          4.2            30.327968             78.046106  \
# 1                          4.7            10.003064             76.307589
# 2                          4.7            18.562450             73.916619
# ...

# %%
df.columns
ratings=df.groupby(['Delivery_person_Age','Delivery_person_Ratings']).size().reset_index().rename(columns={0:'Rating Count'})
ratings
# Out:
#      Delivery_person_Age  Delivery_person_Ratings  Rating Count
# 0                   15.0                      1.0            38
# 1                   20.0                      2.5             2
# 2                   20.0                      2.6             4
# 3                   20.0                      2.7             2
# 4                   20.0                      2.8             2
# ..                   ...                      ...           ...
# 421                 39.0                      4.7           301
# 422                 39.0                      4.8           311
# 423                 39.0                      4.9           290
# 424                 39.0                      5.0           196
# 425                 50.0                      6.0            53
#
# [426 rows x 3 columns]

# %%
# Observations
# #rating between 4.7-6---->Excellent
# rating is between 3.5-4.6 ----> Good
# rating is between 3.5-2.5-----> Average
# rating is between 1.0-2.4-----> Poor

# %%
ratings.head()
# Out:
#    Delivery_person_Age  Delivery_person_Ratings  Rating Count
# 0                 15.0                      1.0            38
# 1                 20.0                      2.5             2
# 2                 20.0                      2.6             4
# 3                 20.0                      2.7             2
# 4                 20.0                      2.8             2

# %%
import matplotlib
matplotlib.rcParams['figure.figsize']=(16,6)
sns.barplot(x='Delivery_person_Age', y='Rating Count',data=ratings)
# Out:
# <Axes: xlabel='Delivery_person_Age', ylabel='Rating Count'>

# %%
sns.barplot(x='Delivery_person_Age', y='Rating Count', hue='Delivery_person_Age',data=ratings, palette=['white','red','orange','yellow','blue','black'])
# Out:
# <Axes: xlabel='Delivery_person_Age', ylabel='Rating Count'>

# %%
save()
# Out:
# '' was not found in history, as a file, url, nor in the user namespace.
